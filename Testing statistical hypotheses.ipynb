# %% [markdown]
# #  Raport 2: Testowanie hipotez statystycznych
# ___
# ## 1.Wstęp:
# * Testowanie hipotez:
#
#     Przeprowadzono weryfikace hipotez, dla dancyh numer $1$ i numer $2$. Dokładnie dla danych numer $1$ z rozkładu Normlanego $N(\mu,0.2)$, na poziomie ufności $\alpha = 0.05$ zweryfikowano hipotezy:
#     * $\mu \neq 1.5$;
#     * $\mu > 1.5$;
#     * $\mu < 1.5$.
#
#     A dla danych numer $2$ z rozkładu Normalnego $N(0.2,\sigma^2)$, na poziomie ufności $\alpha = 0.05$ zweryfikowano hipotezy:
#     * $\sigma^2 \neq 1.5$;
#     * $\sigma^2 > 1.5$;
#     * $\sigma^2 < 1.5$.
#
#     W każdym z przypadków wyznaczono obszary krytyczne i p-wartości. Dodatkowo dla każdej ze zweryfikowanych hipotez dla danych $1$ i danych $2$ wyzanczono symulacyjnie prawdopodobieństwa popełnienia błedu $I$ rodzaju i błedu $II$ rodzaju. Ponadtow wyznaczono moce testów.
# ___

# %% [markdown]
# ## 2.Weryfikacja hipotez:
# ___
# ### 2.1 Zadanie 1: testowanie hipotez dla danych numer $1$ z rozkładu Normlanego $N(\mu,0.2)$, na poziomie ufności $\alpha = 0.05$:
#    * $\mu \neq 1.5$

# %%
#### H1: µ ̸= 1.5
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import pandas as pd
  
data = pd.read_csv("lista8_zad1.txt", header = None)

# Poziom istotności
alpha = 0.05

# Średnia próbki
sample_mean = np.mean(data)

# Odchylenie standardowe populacji
population_std = 0.2

# Liczba obserwacji w próbce
n = len(data)

# Wartość statystyki testowej
z = (sample_mean - 1.5) / (population_std / np.sqrt(n))
#print(z)
# Obszary krytyczne (przyjmując rozkład normalny)
critical_region_left = stats.norm.ppf(alpha/2)
critical_region_right = stats.norm.ppf(1 - alpha/2)

p_value = 2 * (1 - stats.norm.cdf(abs(z)))

x = np.linspace(-7.5, 7.5, 100)
y = stats.norm.pdf(x, 0, 1)

# Wykres obszarów krytycznych
plt.plot(x, y)
plt.fill_between(x[x < critical_region_left], y[x < critical_region_left], color='red')
plt.fill_between(x[x > critical_region_right], y[x > critical_region_right], color='red')
plt.scatter(z,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla µ ̸= 1.5')
plt.xlabel('Wartość statystyki testowej H1')
plt.ylabel('Gęstość')
plt.legend(loc="upper left")
plt.show()

# Wyświetlenie wyników
#print('Wartość statystyki testowej (z-score):', z)
print('Wartości krytyczne dla alternatywy H1: ', critical_region_left, ',', critical_region_right)
print('p-wartość:', p_value)
# Out:
# Wartości krytyczne dla alternatywy H1:  -1.9599639845400545 , 1.959963984540054
# p-wartość: [1.90247817e-12]

# %% [markdown]
# * $\mu > 1.5$;

# %%
#### H2: µ > 1.5
  
data = pd.read_csv("lista8_zad1.txt", header = None)

# Poziom istotności
alpha = 0.05

# Średnia próbki
sample_mean = np.mean(data)

# Odchylenie standardowe populacji
population_std = 0.2

# Liczba obserwacji w próbce
n = len(data)

# Wartość statystyki testowej
z = (sample_mean - 1.5) / (population_std / np.sqrt(n))

# Obszary krytyczne (przyjmując rozkład normalny)
critical_region_right = stats.norm.ppf(1 - alpha)
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

x = np.linspace(-7.5, 7.5, 100)
y = stats.norm.pdf(x, 0, 1)

# Wykres obszarów krytycznych
plt.plot(x, y)
plt.fill_between(x[x > critical_region_right], y[x > critical_region_right], color='red')
plt.scatter(z,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla µ > 1.5')
plt.xlabel('Wartość statystyki testowej H2')
plt.ylabel('Gęstość')
plt.legend(loc="upper left")
plt.show()

# Wyświetlenie wyników
#print('Wartość statystyki testowej (z-score):', z)
print('Wartość krytyczna dla alternatywy H2 (prawostronna): ', critical_region_right)
print('p-wartość:', p_value)
# Out:
# Wartość krytyczna dla alternatywy H2 (prawostronna):  1.6448536269514722
# p-wartość: [1.90247817e-12]

# %% [markdown]
# * $\mu < 1.5$.

# %%
#### H3: µ < 1.5
  
data = pd.read_csv("lista8_zad1.txt", header = None)

# Poziom istotności
alpha = 0.05

# Średnia próbki
sample_mean = np.mean(data)

# Odchylenie standardowe populacji
population_std = 0.2

# Liczba obserwacji w próbce
n = len(data)

# Wartość statystyki testowej
z = (sample_mean - 1.5) / (population_std / np.sqrt(n))

# Obszary krytyczne (przyjmując rozkład normalny)
critical_region_left = stats.norm.ppf(alpha)
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

x = np.linspace(-7.5, 7.5, 100)
y = stats.norm.pdf(x, 0, 1)

# Wykres obszarów krytycznych
plt.plot(x, y)
plt.fill_between(x[x < critical_region_left], y[x < critical_region_left], color='red')
plt.scatter(z,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla µ < 1.5')
plt.xlabel('Wartość statystyki testowej H3')
plt.ylabel('Gęstość')
plt.legend(loc="upper left")
plt.show()

# Wyświetlenie wyników
#print('Wartość statystyki testowej (z-score):', z)
print('Wartość krytyczna dla alternatywy H3 (lewostronna): ', critical_region_left)
print('p-wartość:', p_value)
# Out:
# Wartość krytyczna dla alternatywy H3 (lewostronna):  -1.6448536269514729
# p-wartość: [1.90247817e-12]

# %% [markdown]
# ### 2.1.1 Wnioski:
# Jeśli obliczona przez nas wartość statystki testowej (zielony kwadrat) znajduje się w obszarze krytycznym (czerwone pole), to odrzucamy hipoteze zerową, przyjmując hipoteze alternatywną:
# - Podpunkt 1: $\mu \neq 1.5$, $H_0$ - odrzucamy;
# - Podpunkt 2: $\mu > 1.5$, przyjmujemy - $H_0$;
# - Podpunkt 3: $\mu < 1.5$, $H_0$- odrzucamy.
#
# Następnie na mocy poniższej definicji, odpowiedzaino na pytanie co się stanie kiedy będziemy zminiać poziom ufności testu.
#
# Definicja: relacja międyz poziomem istotności, a poziomem ufności:
#    * $poziom~istotności=\alpha$;
#    * $poziom~ufności=1-\alpha$.
#
# Z powyższej definijci mamy proste wnioski:
# - Kiedy zwiększamy $poziom~istotności=\alpha$, zmniejszamy $poziom~ufności=1-\alpha$;
# - Kiedy zmniejszamy $poziom~istotności=\alpha$, zwiekszamy $poziom~ufności=1-\alpha$.
#
# Zatem, kiedy zwiększymy $poziom~istotności=\alpha$, to zminiejszymy $poziom~ufności=1-\alpha$, a to powoduje powiększenie się obszaru krytycznego, czyli łatwiej nam odrzucić testowaną hipotezze. W sytuacji, gdy zmniejszymy $poziom~istotności=\alpha$, to zwiększymy $poziom~ufności=1-\alpha$, co skutkuje pomniejszeniem obszaru krytycznego, czyli trudniej nam odrzucić testowaną hipoteze.

# %% [markdown]
# ___
# ### 2.2 Zadanie 2: testowanie hipotez dla danych numer $2$ z rozkładu Normlanego $N(0.2,\sigma^2)$, na poziomie ufności $\alpha = 0.05$:
#    * $\sigma^2 \neq 1.5$

# %%
#### H1: sigma^2 != 1.5

from scipy.stats import chi2

# Dane z próby
data = pd.read_csv("lista8_zad2.txt", header = None)

# Parametry rozkładu normalnego
mu = 0.2

# Wielkość próby
n = len(data)

# Obliczenie statystyki testowej
sample_variance = np.var(data, ddof=1)  # Ostrzeżenie: używamy nieobciążonej estymacji wariancji

# Obliczenie statystyki testowej chi-kwadrat
chi_squared = (n - 1) * sample_variance / 1.5

# Obliczenie p-wartości
p_value = 2 * min(chi2.cdf(chi_squared, df=n-1), 1 - chi2.cdf(chi_squared, df=n-1))

# Wyświetlenie wyników dla hipotezy sigma^2 != 1.5
#print("Hipoteza: sigma^2 != 1.5")
#print("Wartość statystyki testowej chi-kwadrat H1:", chi_squared)
#print("P-wartość:", p_value)

# Obszary krytyczne dla hipotezy sigma^2 != 1.5
alpha = 0.05

critical_region_left = chi2.ppf(alpha/2, df=n-1)
critical_region_right = chi2.ppf(1 - alpha/2, df=n-1)

df = n-1
x = np.linspace(800, 1200, 100)
density = chi2.pdf(x, df)

# Wykres obszarów krytycznych
plt.plot(x, density)
plt.fill_between(x[x < critical_region_left], density[x < critical_region_left], color='red')
plt.fill_between(x[x > critical_region_right], density[x > critical_region_right], color='red')
plt.scatter(chi_squared,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla sigma^2 != 1.5')
plt.xlabel('Wartość statystyki testowej H1')
plt.ylabel('Gęstość')
plt.legend(loc='upper left')
plt.show()

print("Wartość krytyczna (lewa): {:.2f}".format(critical_region_left))
print("Wartość krytyczna (prawa): {:.2f}".format(critical_region_right))
print("P-wartość:", p_value)
# Out:
# Wartość krytyczna (lewa): 913.30
# Wartość krytyczna (prawa): 1088.49
# P-wartość: [0.01502325]

# %% [markdown]
# * $\sigma^2 > 1.5$

# %%
#### H2: sigma^2 > 1.5

from scipy.stats import chi2

# Dane z próby
data = pd.read_csv("lista8_zad2.txt", header = None)

# Parametry rozkładu normalnego
mu = 0.2

# Wielkość próby
n = len(data)

# Obliczenie statystyki testowej
sample_variance = np.var(data, ddof=1)  # Ostrzeżenie: używamy nieobciążonej estymacji wariancji

# Obliczenie statystyki testowej chi-kwadrat
chi_squared = (n - 1) * sample_variance / 1.5

# Obliczenie p-wartości
p_value = 1 - chi2.cdf(chi_squared, df=n-1)

# Wyświetlenie wyników dla hipotezy sigma^2 > 1.5
#print("Hipoteza: sigma^2 > 1.5")
#print("Wartość statystyki testowej chi-kwadrat:", chi_squared)


# Obszary krytyczne dla hipotezy sigma^2 > 1.5
alpha = 0.05

critical_region_right = chi2.ppf(1 - alpha, df=n-1)

df = n-1
x = np.linspace(800, 1200, 100)
density = chi2.pdf(x, df)

# Wykres obszarów krytycznych
plt.plot(x, density)
plt.fill_between(x[x > critical_region_right], density[x > critical_region_right], color='red')
plt.scatter(chi_squared,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla sigma^2 > 1.5')
plt.xlabel('Wartość statystyki testowej H2')
plt.ylabel('Gęstość')
plt.legend(loc="upper left")
plt.show()

print("Wartość krytyczna (prawa): {:.2f}".format(critical_region_right))
print("P-wartość:", p_value)
# Out:
# Wartość krytyczna (prawa): 1073.64
# P-wartość: [0.00751163]

# %% [markdown]
# * $\sigma^2 < 1.5$

# %%
#### H3: sigma^2 < 1.5

from scipy.stats import chi2

# Dane z próby
data = pd.read_csv("lista8_zad2.txt", header = None)

# Parametry rozkładu normalnego
mu = 0.2

# Wielkość próby
n = len(data)

# Obliczenie statystyki testowej
sample_variance = np.var(data, ddof=1)  # Ostrzeżenie: używamy nieobciążonej estymacji wariancji

# Obliczenie statystyki testowej chi-kwadrat
chi_squared = (n - 1) * sample_variance / 1.5

# Obliczenie p-wartości
p_value = chi2.cdf(chi_squared, df=n-1)

# Wyświetlenie wyników dla hipotezy sigma^2 < 1.5
#print("Hipoteza: sigma^2 < 1.5")
#print("Wartość statystyki testowej chi-kwadrat:", chi_squared)

# Obszary krytyczne dla hipotezy sigma^2 < 1.5
alpha = 0.05

critical_region_left = chi2.ppf(alpha, df=n-1)

df = n-1
x = np.linspace(800, 1200, 100)
density = chi2.pdf(x, df)

# Wykres obszarów krytycznych
plt.plot(x, density)
plt.fill_between(x[x < critical_region_left], density[x < critical_region_left], color='red')
plt.scatter(chi_squared,0,marker="s",color="g",label="Wartość statystyki testowej")
plt.title('Obszar krytyczny dla sigma^2 < 1.5')
plt.xlabel('Wartość statystyki testowej H3')
plt.ylabel('Gęstość')
plt.legend(loc="upper left")
plt.show()

print("Wartość krytyczna (lewa): {:.2f}".format(critical_region_left))
print("P-wartość:", p_value)
# Out:
# Wartość krytyczna (lewa): 926.63
# P-wartość: [0.99248837]

# %% [markdown]
# ### 2.2.1 Wnioski:
# Jeśli obliczona przez nas wartość statystki testowej (zielony kwadrat) znajduje się w obszarze krytycznym (czerwone pole), to odrzucamy hipoteze zerową, przyjmując hipoteze alternatywną:
# - Podpunkt 1: $\sigma^2 \neq 1.5$, $H_0$ - odrzucamy;
# - Podpunkt 2: $\sigma^2 > 1.5$, $H_0$ - odrzucamy;
# - Podpunkt 3: $\sigma^2 < 1.5$, przyjmujemy - $H_0$.
#
# Następnie na mocy wcześniiej wspomaninej definicji (2.1.1), odpowiedzaino na pytanie co się stanie kiedy będziemy zminiać poziom ufności testu.
#
# Zatem, kiedy zwiększymy $poziom~istotności=\alpha$, to zminiejszymy $poziom~ufności=1-\alpha$, a to powoduje powiększenie się obszaru krytycznego, czyli łatwiej nam odrzucić testowaną hipotezze. W sytuacji, gdy zmniejszymy $poziom~istotności=\alpha$, to zwiększymy $poziom~ufności=a-\alpha$, co skutkuje pomniejszeniem obszaru krytycznego, czyli trudniej nam odrzucić testowaną hipoteze.

# %% [markdown]
# ___
# ### 2.3 Zadanie 3: symulacyjne wyznaczanie prawdopodobieństw popełnienia błedu $I$ rodzaju i $II$ rodzaju oraz mocy testów:
# #### 2.3.1 Dla Zadania 1:
#     Prawdopodbieństwo błedu I rodzaju:
#    * $\mu \neq 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(1.5,0.2,size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    population_std = 0.2

    # Wartość statystyki testowej
    Z = (sample_mean - 1.5) / (population_std / np.sqrt(n))
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left0 = stats.norm.ppf(alpha[0]/2)
    critical_region_right0 = stats.norm.ppf(1 - alpha[0]/2)
    critical_region_left1 = stats.norm.ppf(alpha[1]/2)
    critical_region_right1 = stats.norm.ppf(1 - alpha[1]/2)
    critical_region_left2 = stats.norm.ppf(alpha[2]/2)
    critical_region_right2 = stats.norm.ppf(1 - alpha[2]/2)
    
    if Z<critical_region_left0:
        count0=count0+1
    elif Z>critical_region_right0:
        count0=count0+1
    if Z<critical_region_left1:
        count1=count1+1
    elif Z>critical_region_right1:
        count1=count1+1
    if Z<critical_region_left2:
        count2=count2+1
    elif Z>critical_region_right2:
        count2=count2+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.003
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.034
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.134

# %% [markdown]
#    * $\mu > 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Symulacyjna próbka
X = np.random.normal(1.5,0.2,size=n)
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(1.5,0.2,size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    population_std = 0.2

    # Wartość statystyki testowej
    Z = (sample_mean - 1.5) / (population_std / np.sqrt(n))
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_right0 = stats.norm.ppf(1 - alpha[0])
    critical_region_right1 = stats.norm.ppf(1 - alpha[1])
    critical_region_right2 = stats.norm.ppf(1 - alpha[2])
    
    if Z>critical_region_right0:
        count0=count0+1
    if Z>critical_region_right1:
        count1=count1+1
    if Z>critical_region_right2:
        count2=count2+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.009
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.044
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.14

# %% [markdown]
#    * $\mu < 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Symulacyjna próbka
X = np.random.normal(1.5,0.2,size=n)
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(1.5,0.2,size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    population_std = 0.2

    # Wartość statystyki testowej
    Z = (sample_mean - 1.5) / (population_std / np.sqrt(n))
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left0 = stats.norm.ppf(alpha[0])
    critical_region_left1 = stats.norm.ppf(alpha[1])
    critical_region_left2 = stats.norm.ppf(alpha[2])
    
    if Z<critical_region_left0:
        count0=count0+1
    if Z<critical_region_left1:
        count1=count1+1
    if Z<critical_region_left2:
        count2=count2+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.008
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.046
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.148

# %% [markdown]
#     Prawdopodobięnstwo błedu II rodzaju i Moc Testów:
#    * $\mu \neq 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
count7=0
count8=0
count9=0
k=0
# Symulacyjna próbka
mi=[1.45,1.46,1.47,1.48,1.49,1.51,1.52,1.53,1.54,1.55]

# Poziom istotności
alpha = 0.05
for k in range(1000):
    
    # Symulacyjna próbka
    X0 = np.random.normal(mi[0],0.2,size=n)
    X1 = np.random.normal(mi[1],0.2,size=n)
    X2 = np.random.normal(mi[2],0.2,size=n)
    X3 = np.random.normal(mi[3],0.2,size=n)
    X4 = np.random.normal(mi[4],0.2,size=n)
    X5 = np.random.normal(mi[5],0.2,size=n)
    X6 = np.random.normal(mi[6],0.2,size=n)
    X7 = np.random.normal(mi[7],0.2,size=n)
    X8 = np.random.normal(mi[8],0.2,size=n)
    X9 = np.random.normal(mi[9],0.2,size=n)
    # Średnia próbki
    sample_mean0 = np.mean(X0)
    sample_mean1 = np.mean(X1)
    sample_mean2 = np.mean(X2)
    sample_mean3 = np.mean(X3)
    sample_mean4 = np.mean(X4)
    sample_mean5 = np.mean(X5)
    sample_mean6 = np.mean(X6)
    sample_mean7 = np.mean(X7)
    sample_mean8 = np.mean(X8)
    sample_mean9 = np.mean(X9)

    # Odchylenie standardowe populacji
    population_std = 0.2

    # Wartość statystyki testowej
    Z0 = (sample_mean0 - 1.5) / (population_std / np.sqrt(n))
    Z1 = (sample_mean1 - 1.5) / (population_std / np.sqrt(n))
    Z2 = (sample_mean2 - 1.5) / (population_std / np.sqrt(n))
    Z3 = (sample_mean3 - 1.5) / (population_std / np.sqrt(n))
    Z4 = (sample_mean4 - 1.5) / (population_std / np.sqrt(n))
    Z5 = (sample_mean5 - 1.5) / (population_std / np.sqrt(n))
    Z6 = (sample_mean6 - 1.5) / (population_std / np.sqrt(n))
    Z7 = (sample_mean7 - 1.5) / (population_std / np.sqrt(n))
    Z8 = (sample_mean8 - 1.5) / (population_std / np.sqrt(n))
    Z9 = (sample_mean9 - 1.5) / (population_std / np.sqrt(n))
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left = stats.norm.ppf(alpha/2)
    critical_region_right = stats.norm.ppf(1 - alpha/2)
   
    if Z0>critical_region_left and Z0<critical_region_right:
        count0=count0+1
    if Z1>critical_region_left and Z1<critical_region_right:
        count1=count1+1
    if Z2>critical_region_left and Z2<critical_region_right:
        count2=count2+1
    if Z3>critical_region_left and Z3<critical_region_right:
        count3=count3+1
    if Z4>critical_region_left and Z4<critical_region_right:
        count4=count4+1
    if Z5>critical_region_left and Z5<critical_region_right:
        count5=count5+1
    if Z6>critical_region_left and Z6<critical_region_right:
        count6=count6+1
    if Z7>critical_region_left and Z7<critical_region_right:
        count7=count7+1
    if Z8>critical_region_left and Z8<critical_region_right:
        count8=count8+1
    if Z9>critical_region_left and Z9<critical_region_right:
        count9=count9+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju = ", float(count0/n), ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
print("Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju = ", count5/n, ",a Moc Testu =", 1 -count5/n)
print("Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju = ", count6/n, ",a Moc Testu =", 1 -count6/n)
print("Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju = ", count7/n, ",a Moc Testu =", 1 -count7/n)
print("Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju = ", count8/n, ",a Moc Testu =", 1 -count8/n)
print("Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju = ", count9/n, ",a Moc Testu =", 1 -count9/n)
# Out:
# Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju =  0.006 ,a Moc Testu = 0.994
# Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju =  0.117 ,a Moc Testu = 0.883
# Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju =  0.637 ,a Moc Testu = 0.363
# Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju =  0.639 ,a Moc Testu = 0.361
# Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju =  0.134 ,a Moc Testu = 0.866
# Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju =  0.005 ,a Moc Testu = 0.995
# Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0

# %% [markdown]
# * $\mu > 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
k=0
# Symulacyjna próbka
mi=[1.51,1.52,1.53,1.54,1.55]

# Poziom istotności
alpha = 0.05
for k in range(n):
    
    # Symulacyjna próbka
    X0 = np.random.normal(mi[0],0.2,size=n)
    X1 = np.random.normal(mi[1],0.2,size=n)
    X2 = np.random.normal(mi[2],0.2,size=n)
    X3 = np.random.normal(mi[3],0.2,size=n)
    X4 = np.random.normal(mi[4],0.2,size=n)
    
    # Średnia próbki
    sample_mean0 = np.mean(X0)
    sample_mean1 = np.mean(X1)
    sample_mean2 = np.mean(X2)
    sample_mean3 = np.mean(X3)
    sample_mean4 = np.mean(X4)
    
     # Odchylenie standardowe populacji
    population_std = 0.2
    
    Z0 = (sample_mean0 - 1.5) / (population_std / np.sqrt(n))
    Z1 = (sample_mean1 - 1.5) / (population_std / np.sqrt(n))
    Z2 = (sample_mean2 - 1.5) / (population_std / np.sqrt(n))
    Z3 = (sample_mean3 - 1.5) / (population_std / np.sqrt(n))
    Z4 = (sample_mean4 - 1.5) / (population_std / np.sqrt(n))


    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_right = stats.norm.ppf(1 - alpha)
    
    if Z0<critical_region_right:
        count0=count0+1
    if Z1<critical_region_right:
        count1=count1+1
    if Z2<critical_region_right:
        count2=count2+1
    if Z3<critical_region_right:
        count3=count3+1
    if Z4<critical_region_right:
        count4=count4+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()

print("Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju = ", count0/n, ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
# Out:
# Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju =  0.541 ,a Moc Testu = 0.45899999999999996
# Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju =  0.069 ,a Moc Testu = 0.931
# Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju =  0.001 ,a Moc Testu = 0.999
# Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0

# %% [markdown]
# * $\mu < 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
k=0
# Symulacyjna próbka
mi=[1.45,1.46,1.47,1.48,1.49]

# Poziom istotności
alpha = 0.05
for k in range(n):
    
    # Symulacyjna próbka
    X0 = np.random.normal(mi[0],0.2,size=n)
    X1 = np.random.normal(mi[1],0.2,size=n)
    X2 = np.random.normal(mi[2],0.2,size=n)
    X3 = np.random.normal(mi[3],0.2,size=n)
    X4 = np.random.normal(mi[4],0.2,size=n)
    
    # Średnia próbki
    sample_mean0 = np.mean(X0)
    sample_mean1 = np.mean(X1)
    sample_mean2 = np.mean(X2)
    sample_mean3 = np.mean(X3)
    sample_mean4 = np.mean(X4)
    
    # Odchylenie standardowe populacji
    population_std = 0.2
    
    Z0 = (sample_mean0 - 1.5) / (population_std / np.sqrt(n))
    Z1 = (sample_mean1 - 1.5) / (population_std / np.sqrt(n))
    Z2 = (sample_mean2 - 1.5) / (population_std / np.sqrt(n))
    Z3 = (sample_mean3 - 1.5) / (population_std / np.sqrt(n))
    Z4 = (sample_mean4 - 1.5) / (population_std / np.sqrt(n))

    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left = stats.norm.ppf(alpha)
  
    if Z0>critical_region_left:
        count0=count0+1
    if Z1>critical_region_left:
        count1=count1+1
    if Z2>critical_region_left:
        count2=count2+1
    if Z3>critical_region_left:
        count3=count3+1
    if Z4>critical_region_left:
        count4=count4+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla mi=1.45, Prawdopodobieństwo Błedu II Rodzaju = ", count0/n, ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
# Out:
# Dla mi=1.45, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju =  0.0 ,a Moc Testu = 1.0
# Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju =  0.065 ,a Moc Testu = 0.935
# Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju =  0.546 ,a Moc Testu = 0.45399999999999996

# %% [markdown]
# #### 2.3.2 Dla Zadania 2:
#     Prawdopodbieństwo błedu I rodzaju:
#    * $\sigma^2 \neq 1.5$;

# %%
from scipy.stats import chi2
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(0.2,np.sqrt(1.5),size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    sample_variance = np.var(X, ddof=1)
    
    # Wartość statystyki testowej
    Z = ((n - 1) * sample_variance) / 1.5
    
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład chi2)
    critical_region_left0 = chi2.ppf(alpha[0]/2, df=n-1)
    critical_region_right0 = chi2.ppf(1 - alpha[0]/2, df=n-1)
    critical_region_left1 = chi2.ppf(alpha[1]/2, df=n-1)
    critical_region_right1 = chi2.ppf(1 - alpha[1]/2, df=n-1)
    critical_region_left2 = chi2.ppf(alpha[2]/2, df=n-1)
    critical_region_right2 = chi2.ppf(1 - alpha[2]/2, df=n-1)
    
    if Z<critical_region_left0:
        count0=count0+1
    elif Z>critical_region_right0:
        count0=count0+1
    if Z<critical_region_left1:
        count1=count1+1
    elif Z>critical_region_right1:
        count1=count1+1
    if Z<critical_region_left2:
        count2=count2+1
    elif Z>critical_region_right2:
        count2=count2+1
    k=k+1

print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.006
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.063
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.167

# %% [markdown]
#    * $\sigma^2 > 1.5$;

# %%
from scipy.stats import chi2
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(0.2,np.sqrt(1.5),size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    sample_variance = np.var(X, ddof=1)
    
    # Wartość statystyki testowej
    Z = ((n - 1) * sample_variance) / 1.5
    
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład chi2)
    critical_region_right0 = chi2.ppf(1 - alpha[0], df=n-1)
    critical_region_right1 = chi2.ppf(1 - alpha[1], df=n-1)
    critical_region_right2 = chi2.ppf(1 - alpha[2], df=n-1)
    
    if Z>critical_region_right0:
        count0=count0+1
    if Z>critical_region_right1:
        count1=count1+1
    if Z>critical_region_right2:
        count2=count2+1
    k=k+1

print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.013
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.052
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.153

# %% [markdown]
#
#    * $\sigma^2 < 1.5$;

# %%
from scipy.stats import chi2
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
k=0
x=[]
y=[]
# Poziom istotności
alpha = [0.01,0.05,0.15]
for k in range(n):
    
    # Symulacyjna próbka
    X = np.random.normal(0.2,np.sqrt(1.5),size=n)
    
    # Średnia próbki
    sample_mean = np.mean(X)

    # Odchylenie standardowe populacji
    sample_variance = np.var(X, ddof=1)
    
    # Wartość statystyki testowej
    Z = ((n - 1) * sample_variance) / 1.5
    
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład chi2)
    critical_region_left0 = chi2.ppf(alpha[0], df=n-1)
    critical_region_left1 = chi2.ppf(alpha[1], df=n-1)
    critical_region_left2 = chi2.ppf(alpha[2], df=n-1)
    
    if Z<critical_region_left0:
        count0=count0+1
    if Z<critical_region_left1:
        count1=count1+1
    if Z<critical_region_left2:
        count2=count2+1
    k=k+1

print("Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju = ", count0/n)
print("Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju = ", count1/n)
print("Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju = ", count2/n)
# Out:
# Dla alfy=0.01, Prawdopodobieństwo Błedu I Rodzaju =  0.012
# Dla alfy=0.05, Prawdopodobieństwo Błedu I Rodzaju =  0.051
# Dla alfy=0.15, Prawdopodobieństwo Błedu I Rodzaju =  0.151

# %% [markdown]
#     Prawdopodobięnstwo błedu II rodzaju i Moc Testów:
#    * $\sigma^2 \neq 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
count7=0
count8=0
count9=0
k=0
# Symulacyjna próbka
s=[1.45,1.46,1.47,1.48,1.49,1.51,1.52,1.53,1.54,1.55]

# Poziom istotności
alpha = 0.05
for k in range(1000):
    
    # Symulacyjna próbka
    X0 = np.random.normal(0.2,np.sqrt(s[0]),size=n)
    X1 = np.random.normal(0.2,np.sqrt(s[1]),size=n)
    X2 = np.random.normal(0.2,np.sqrt(s[2]),size=n)
    X3 = np.random.normal(0.2,np.sqrt(s[3]),size=n)
    X4 = np.random.normal(0.2,np.sqrt(s[4]),size=n)
    X5 = np.random.normal(0.2,np.sqrt(s[5]),size=n)
    X6 = np.random.normal(0.2,np.sqrt(s[6]),size=n)
    X7 = np.random.normal(0.2,np.sqrt(s[7]),size=n)
    X8 = np.random.normal(0.2,np.sqrt(s[8]),size=n)
    X9 = np.random.normal(0.2,np.sqrt(s[9]),size=n)
    
    
     
    sample_variance0 = np.var(X0, ddof=1)
    sample_variance1 = np.var(X1, ddof=1)
    sample_variance2 = np.var(X2, ddof=1)
    sample_variance3 = np.var(X3, ddof=1)
    sample_variance4 = np.var(X4, ddof=1)
    sample_variance5 = np.var(X5, ddof=1)
    sample_variance6 = np.var(X6, ddof=1)
    sample_variance7 = np.var(X7, ddof=1)
    sample_variance8 = np.var(X8, ddof=1)
    sample_variance9 = np.var(X9, ddof=1)

    # Wartość statystyki testowej
    Z0 = (n - 1) * sample_variance0 / 1.5
    Z1 = (n - 1) * sample_variance1 / 1.5
    Z2 = (n - 1) * sample_variance2 / 1.5
    Z3 = (n - 1) * sample_variance3 / 1.5
    Z4 = (n - 1) * sample_variance4 / 1.5
    Z5 = (n - 1) * sample_variance5 / 1.5
    Z6 = (n - 1) * sample_variance6 / 1.5
    Z7 = (n - 1) * sample_variance7 / 1.5
    Z8 = (n - 1) * sample_variance8 / 1.5
    Z9 = (n - 1) * sample_variance9 / 1.5
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left = chi2.ppf(alpha/2, df=n-1)
    critical_region_right = chi2.ppf(1 - alpha/2, df=n-1)

   
    if Z0>critical_region_left and Z0<critical_region_right:
        count0=count0+1
    if Z1>critical_region_left and Z1<critical_region_right:
        count1=count1+1
    if Z2>critical_region_left and Z2<critical_region_right:
        count2=count2+1
    if Z3>critical_region_left and Z3<critical_region_right:
        count3=count3+1
    if Z4>critical_region_left and Z4<critical_region_right:
        count4=count4+1
    if Z5>critical_region_left and Z5<critical_region_right:
        count5=count5+1
    if Z6>critical_region_left and Z6<critical_region_right:
        count6=count6+1
    if Z7>critical_region_left and Z7<critical_region_right:
        count7=count7+1
    if Z8>critical_region_left and Z8<critical_region_right:
        count8=count8+1
    if Z9>critical_region_left and Z9<critical_region_right:
        count9=count9+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju = ", float(count0/n), ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
print("Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju = ", count5/n, ",a Moc Testu =", 1 -count5/n)
print("Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju = ", count6/n, ",a Moc Testu =", 1 -count6/n)
print("Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju = ", count7/n, ",a Moc Testu =", 1 -count7/n)
print("Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju = ", count8/n, ",a Moc Testu =", 1 -count8/n)
print("Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju = ", count9/n, ",a Moc Testu =", 1 -count9/n)
# Out:
# Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju =  0.892 ,a Moc Testu = 0.10799999999999998
# Dla mi=1.46, Prawdopodobieństwo Błedu II Rodzaju =  0.901 ,a Moc Testu = 0.09899999999999998
# Dla mi=1.47, Prawdopodobieństwo Błedu II Rodzaju =  0.928 ,a Moc Testu = 0.07199999999999995
# Dla mi=1.48, Prawdopodobieństwo Błedu II Rodzaju =  0.934 ,a Moc Testu = 0.06599999999999995
# Dla mi=1.49, Prawdopodobieństwo Błedu II Rodzaju =  0.949 ,a Moc Testu = 0.051000000000000045
# Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju =  0.936 ,a Moc Testu = 0.06399999999999995
# Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju =  0.943 ,a Moc Testu = 0.05700000000000005
# Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju =  0.925 ,a Moc Testu = 0.07499999999999996
# Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju =  0.917 ,a Moc Testu = 0.08299999999999996
# Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju =  0.888 ,a Moc Testu = 0.11199999999999999

# %% [markdown]
# * $\sigma^2 > 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
count7=0
count8=0
count9=0
k=0
# Symulacyjna próbka
s=[1.51,1.52,1.53,1.54,1.55]

# Poziom istotności
alpha = 0.05
for k in range(1000):
    
    # Symulacyjna próbka
    X0 = np.random.normal(0.2,np.sqrt(s[0]),size=n)
    X1 = np.random.normal(0.2,np.sqrt(s[1]),size=n)
    X2 = np.random.normal(0.2,np.sqrt(s[2]),size=n)
    X3 = np.random.normal(0.2,np.sqrt(s[3]),size=n)
    X4 = np.random.normal(0.2,np.sqrt(s[4]),size=n)
    
    sample_variance0 = np.var(X0, ddof=1)
    sample_variance1 = np.var(X1, ddof=1)
    sample_variance2 = np.var(X2, ddof=1)
    sample_variance3 = np.var(X3, ddof=1)
    sample_variance4 = np.var(X4, ddof=1)

    # Wartość statystyki testowej
    Z0 = (n - 1) * sample_variance0 / 1.5
    Z1 = (n - 1) * sample_variance1 / 1.5
    Z2 = (n - 1) * sample_variance2 / 1.5
    Z3 = (n - 1) * sample_variance3 / 1.5
    Z4 = (n - 1) * sample_variance4 / 1.5
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_right = chi2.ppf(1 - alpha, df=n-1)
   
    if Z0<critical_region_right:
        count0=count0+1
    if Z1<critical_region_right:
        count1=count1+1
    if Z2<critical_region_right:
        count2=count2+1
    if Z3<critical_region_right:
        count3=count3+1
    if Z4<critical_region_right:
        count4=count4+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju = ", count0/n, ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
# Out:
# Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju =  0.94 ,a Moc Testu = 0.06000000000000005
# Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju =  0.907 ,a Moc Testu = 0.09299999999999997
# Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju =  0.885 ,a Moc Testu = 0.11499999999999999
# Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju =  0.826 ,a Moc Testu = 0.17400000000000004
# Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju =  0.813 ,a Moc Testu = 0.18700000000000006

# %% [markdown]
# * $\sigma^2 < 1.5$;

# %%
n = 1000
# Zmienne i tablice pomocnicze
count0=0
count1=0
count2=0
count3=0
count4=0
count5=0
count6=0
count7=0
count8=0
count9=0
k=0
# Symulacyjna próbka
s=[1.45,1.46,1.47,1.48,1.49]

# Poziom istotności
alpha = 0.05
for k in range(1000):
    
    # Symulacyjna próbka
    X0 = np.random.normal(0.2,np.sqrt(s[0]),size=n)
    X1 = np.random.normal(0.2,np.sqrt(s[1]),size=n)
    X2 = np.random.normal(0.2,np.sqrt(s[2]),size=n)
    X3 = np.random.normal(0.2,np.sqrt(s[3]),size=n)
    X4 = np.random.normal(0.2,np.sqrt(s[4]),size=n)
    
    sample_variance0 = np.var(X0, ddof=1)
    sample_variance1 = np.var(X1, ddof=1)
    sample_variance2 = np.var(X2, ddof=1)
    sample_variance3 = np.var(X3, ddof=1)
    sample_variance4 = np.var(X4, ddof=1)

    # Wartość statystyki testowej
    Z0 = (n - 1) * sample_variance0 / 1.5
    Z1 = (n - 1) * sample_variance1 / 1.5
    Z2 = (n - 1) * sample_variance2 / 1.5
    Z3 = (n - 1) * sample_variance3 / 1.5
    Z4 = (n - 1) * sample_variance4 / 1.5
    #### H1: µ ̸= 1.5
    
    # Obszary krytyczne (przyjmując rozkład normalny)
    critical_region_left = chi2.ppf(alpha, df=n-1)
   
    if Z0>critical_region_left:
        count0=count0+1
    if Z1>critical_region_left:
        count1=count1+1
    if Z2>critical_region_left:
        count2=count2+1
    if Z3>critical_region_left:
        count3=count3+1
    if Z4>critical_region_left:
        count4=count4+1
    #x.append(alpha[k])
    #y.append(count/n)
    #plt.scatter(x,Y)
    k=k+1
#plt.scatter(x[49],0.05,color="r",label="Poziom istotności = 0.05")
#print("Dla alphy 0.05, Prawdopodobieństwo błęd I rodzaju =",x[49])
#plt.title('Zależność międy poziomem istotności, a prawdopodobieństwem błedu I rodzaju')
#plt.xlabel('Prawdopodobieństwo błędu I rozdaju')
#plt.ylabel('Poziom istotności')
#plt.scatter(0.05,y[49],color="r")
#plt.legend()
#plt.show()
print("Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju = ", count0/n, ",a Moc Testu =", 1 -count0/n)
print("Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju = ", count1/n, ",a Moc Testu =", 1 -count1/n)
print("Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju = ", count2/n, ",a Moc Testu =", 1 -count2/n)
print("Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju = ", count3/n, ",a Moc Testu =", 1 -count3/n)
print("Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju = ", count4/n, ",a Moc Testu =", 1 -count4/n)
# Out:
# Dla mi=1.51, Prawdopodobieństwo Błedu II Rodzaju =  0.823 ,a Moc Testu = 0.17700000000000005
# Dla mi=1.52, Prawdopodobieństwo Błedu II Rodzaju =  0.868 ,a Moc Testu = 0.132
# Dla mi=1.53, Prawdopodobieństwo Błedu II Rodzaju =  0.897 ,a Moc Testu = 0.10299999999999998
# Dla mi=1.54, Prawdopodobieństwo Błedu II Rodzaju =  0.918 ,a Moc Testu = 0.08199999999999996
# Dla mi=1.55, Prawdopodobieństwo Błedu II Rodzaju =  0.936 ,a Moc Testu = 0.06399999999999995

# %% [markdown]
# ## 3. Wnioski końcowe

# %% [markdown]
# Kiedy zwiększymy $poziom~istotności=\alpha$, to zminiejszymy $poziom~ufności=1-\alpha$, a to powoduje powiększenie się obszaru krytycznego, czyli łatwiej nam odrzucić testowaną hipoteze. W sytuacji, gdy zmniejszymy $poziom~istotności=\alpha$, to zwiększymy $poziom~ufności=1-\alpha$, co skutkuje pomniejszeniem obszaru krytycznego, czyli trudniej nam odrzucić testowaną hipoteze.
#
# W przypadku testowania średnich, błąd I rodzaju oznaczałby, że odrzucamy hipotezę zerową, sugerując istnienie różnicy między średnimi grup, podczas gdy tak naprawdę nie ma żadnej różnicy. Błąd II rodzaju oznaczałby natomiast, że nie odrzucamy hipotezy zerowej, pomimo istnienia różnicy między średnimi grup.
#
# W przypadku testowania wariancji, błąd I oznaczałby, że odrzucamy hipotezę zerową, sugerując istnienie różnic w wariancji między grupami, podczas gdy tak naprawdę nie ma żadnych różnic. Błąd II oznaczałby natomiast, że nie odrzucamy hipotezy zerowej, pomimo istnienia różnic w wariancji między grupami.
#
# Wnioskować możemy, że błąd I i II rodzaju zależy od poziomu istotności testu co wskazują nasze obliczenia.
#
# Dla zadanej alternatywnej wartości paramteru prawdopodobieństwo odrzucenia fałszywej hipotezy zerowej i przyjęciu prawdziwej hipotezy alternatywnej nazywamy mocą testu. Wyższa wartość mocy testu oznacza większą zdolność testu do wykrycia różnic lub związków.
#
# Przy zadanym poziomie istotności i liczności próby losowej moc testu rośnie wraz ze wzrostem odległości rzeczywistej wartości parametru, a wartością statystyki.
